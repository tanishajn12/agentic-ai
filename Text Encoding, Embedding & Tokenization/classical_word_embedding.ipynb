# %%
from gensim.models import Word2Vec, KeyedVectors
import gensim.downloader as api

# %%
model = api.load("word2vec-google-news-300")
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model = api.load("word2vec-google-news-300")
#
# File c:\Users\tanis\Desktop\agentic ai bootcamp\Text Encoding, Embedding & Tokenization\env\Lib\site-packages\gensim\downloader.py:496, in load(name, return_path)
#     494 path = os.path.join(folder_dir, file_name)
#     495 if not os.path.exists(folder_dir):
# --> 496     _download(name)
#     498 if return_path:
#     499     return path
#
# File c:\Users\tanis\Desktop\agentic ai bootcamp\Text Encoding, Embedding & Tokenization\env\Lib\site-packages\gensim\downloader.py:365, in _download(name)
#     363 tmp_dir = tempfile.mkdtemp()
#     364 init_path = os.path.join(tmp_dir, "__init__.py")
# --> 365 urllib.urlretrieve(url_load_file, init_path)
#     366 total_parts = _get_parts(name)
#     367 if total_parts > 1:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:240, in urlretrieve(url, filename, reporthook, data)
#     223 """
#     224 Retrieve a URL into a temporary location on disk.
#     225
#    (...)    236 data file as well as the resulting HTTPMessage object.
#     237 """
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#     243     # Just return the local path and the "headers" for file://
#     244     # URLs. No sense in performing a copy unless requested.
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:521, in OpenerDirector.open(self, fullurl, data, timeout)
#     519 for processor in self.process_response.get(protocol, []):
#     520     meth = getattr(processor, meth_name)
# --> 521     response = meth(req, response)
#     523 return response
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:630, in HTTPErrorProcessor.http_response(self, request, response)
#     627 # According to RFC 2616, "2xx" code indicates that the client's
#     628 # request was successfully received, understood, and accepted.
#     629 if not (200 <= code < 300):
# --> 630     response = self.parent.error(
#     631         'http', request, response, code, msg, hdrs)
#     633 return response
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:553, in OpenerDirector.error(self, proto, *args)
#     551     http_err = 0
#     552 args = (dict, proto, meth_name) + args
# --> 553 result = self._call_chain(*args)
#     554 if result:
#     555     return result
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:745, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     742 fp.read()
#     743 fp.close()
# --> 745 return self.parent.open(new, timeout=req.timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
# -> 1348     r = h.getresponse()
#    1349 except:
#    1350     h.close()
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:305, in HTTPResponse._read_status(self)
#     301     print("reply:", repr(line))
#     302 if not line:
#     303     # Presumably, the server closed the connection before
#     304     # sending a valid response.
# --> 305     raise RemoteDisconnected("Remote end closed connection without"
#     306                              " response")
#     307 try:
#     308     version, status, reason = line.split(None, 2)
#
# RemoteDisconnected: Remote end closed connection without response

# %%
model["sunny"]

# %%
len(model["sunny"])

# %%
model["men"]

# %%
len(model["men"])

# %%
model.most_similar("king", topn=5)
model.most_similar("sunny", topn=5)

# %%
model.most_similar("cricket", topn=10)

# %%
model.similarity("king", "queen")
model.similarity("man", "woman")
model.similarity("king", "car")

# %%
model.similarity("man", "java")

# %%
model.similarity("sunny", "Sunny")

# %%
model.similarity("python", "java")

# %%
model.doesnt_match(["PHP", "JAVA", "DOG", "C++"])
model.doesnt_match(["breakfast", "lunch", "dinner", "car"])

# %%
vec=model["king"] - model["man"] + model["woman"]

# %%
model.most_similar([vec])
